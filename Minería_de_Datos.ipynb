# %% [markdown]
# <a href="https://colab.research.google.com/github/AdriannMo/Mineria_de_Datos/blob/main/Miner%C3%ADa_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Minería de Datos

# %% [markdown]
# ##Primer Parcial

# %% [markdown]
# ##Introducción

# %% [markdown]
# ####Conceptos
#
# ¿Qué es la Minería de Datos? La minería de datos es el proceso de detectar patrones, tendencias y anomalías en grandes conjuntos de datos para convertirlos en información comprensible y útil.

# %% [markdown]
# ####Ciencia de Datos
#
# Ayuda y Documentación de Python

# %%
#La función help nos muestra la ayuda
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
#La otra forma de obtener ayuda es utilizando "?"
len?

# %%
L = [1, 2, 3]
L.insert?

# %%
#Otro ejemplo de ayuda
L?

# %%
def square(a):
  ###Return the square of a.###
  return a ** 2

# %%
square?
